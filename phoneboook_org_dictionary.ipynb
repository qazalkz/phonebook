# %% [markdown]
# <a href="https://colab.research.google.com/github/qazalkz/phonebook/blob/main/phoneboook_org_dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contact={}
print(''' phone book
    1. add contact
    2.delet contact
    3.search contact
    4.display all
    5.Quit''')

def add_contact(name, number):
    contact[name]=number
    print(name, 'added to phone book!')

def dell_contact(name):
  while name not in contact:
    print('not found!')
    name=input('enter again: ')
  print(name, ' deleted')
  del contact[name]

def search_contact(name):
    while name not in contact:
        print('not found!')
        name=input('enter again: ')  
    print(name, 'number is :',  contact[name])   
     
def disp_contact():
    if len(contact)==0:
       print('phone book is empty!')
    else:
      print('are phone book contacts ')      
      for i in contact:
        print(i, end=' ')
   
def main_def(num):
    if num == 1:
        add_contact(input('enter the name: '),input('enter the number: '))   
    elif num == 2:
        dell_contact(input('enter the name: '))  
    elif num == 3:
        search_contact(input('enter the name: '))
    elif num == 4:
        disp_contact()
    elif num == 5:
        print('bye bye')
        exit(0)
        
        

#while True:
x = int(input(' enter a number: '))
main_def(x)

# %% [markdown]
# #last updat

# %%
contact={}
print(''' phone book
    1. add contact
    2.delete contact
    3.search contact
    4.display all
    5.update contact
    6.Quit''')

def add_contact(name, number):
    contact[name]=number
    print(name, 'added to phone book!')

def dell_contact(name):
  while name not in contact:
    print('not found!')
    name=input('enter again: ')
  print(name, ' deleted')
  del contact[name]


def search_contact(name):
    while name not in contact:
        print('not found!')
        name=input('enter again: ')  
    print(name, 'number is :',  contact[name])   
     
def disp_contact():
    if len(contact)==0:
       print('phone book is empty!')
    else:
      print('are phone book contacts ')      
      for i in contact:
        print(i, end=' ')

def update_contact(name):
    while name not in contact:
      print('not found!')
      name=input('enter again: ')
      
    number=input('enter the new number: ')
    print(name,'number changed to ', number)
    contact[name]=number 


   
def main_def(num):
    
    if num == 1:
        add_contact(input('enter the name: '),input('enter the number: '))   
    elif num == 2:
        dell_contact(input('enter the name: ')) 
        
    elif num == 3:
        search_contact(input('enter the name: '))
    elif num == 4:
        disp_contact()
    elif num==5:
      update_contact(input('enter the name: '))

    elif num == 6:
        print('bye bye')
        exit(0)
        
        

while True:
  x = int(input(' enter a number: '))
  main_def(x)

# %% [markdown]
# # final

# %%
contact={}
print(''' phone book
    1. add contact
    2.delete contact
    3.search contact
    4.display all
    5.update contact
    6.Quit''')

def add_contact(name, number):
    contact[name]=number
    print(name, 'added to phone book!')

def dell_contact(name):
  while name not in contact:
    print('not found!')
    name=input('enter again: ')
  print(name, ' deleted')
  del contact[name]


def search_contact(name):
    while name not in contact:
        print('not found!')
        name=input('enter again: ')  
    print(name, 'number is :',  contact[name])   
     
def disp_contact():
    if len(contact)==0:
       print('phone book is empty!')
    else:
      print('are phone book contacts ')      
      for i in contact:
        print(i, end=' ')

def update_contact(name):
    while name not in contact:
      print('not found!')
      name=input('enter again: ')
      
    number=input('enter the new number: ')
    print(name,'number changed to ', number)
    contact[name]=number 


  
   
def main_def(num):
    
    if num == 1:
        name=input('enter the name: ')
        number=input('enter the number: ')
        add_contact(name,number)   
    elif num == 2:
        name=input('enter the name: ')
        dell_contact(name) 
        
    elif num == 3:
        name=input('enter the name: ')
        search_contact(name)
    elif num == 4:
        disp_contact()
    elif num==5:
      name=input('enter the name: ')
      update_contact(name)

    elif num == 6:
        print('bye bye')
        exit(0)
        
        

while True:
  x = int(input(' enter a number: '))
  main_def(x)
# Out:
#  phone book
#     1. add contact
#     2.delete contact
#     3.search contact
#     4.display all
#     5.update contact
#     6.Quit
#  enter a number: 1
# enter the name: gh
# enter the number: 63
# gh added to phone book!
